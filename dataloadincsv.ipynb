# %%
import mysql.connector
import csv


config = {
    'user': '****',
    'password': '****',
    'host': '*****',     
    'port': 3306,
    'database': 'fb_shipper_staging'
}
csv_file_path = 'Downloads/vendor-status-staging - Sheet1.csv'

try:
  
    conn = mysql.connector.connect(**config)
    cursor = conn.cursor()


    query = "select vendor_id , company_status from shipper_company sc where sc.`type` = 'FORWARDER' "
    cursor.execute(query)

    
    rows = cursor.fetchall()

    l=[]
    for row in rows:
        c=list(row)
        b=[]
        for i in range(len(c)):
            if c[i] is None and i!=0:
                c[i]="Active"
            #print(c[i])
            if c[0] is not None:
                b.append(c[i])
        l.append(b)

    # print("*****")
    print(len(l))
    print("*******")
    print(l)
    # for row in rows:
    #     print(row)
    # for i in l:
    #     for j in i:
    #         if j is None:
                
    #             print("Hi")
    
    # for row in rows:
    #     b=[]
    #     for i in row:
    #         b.append(i)
    #         if str(i)=="None":
    #             b[1]="Active"
    #             #print("HI")
    #         print(b)
            
        
    column_names = [i[0] for i in cursor.description]

    with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(column_names) 
        writer.writerows(l)         

    


except mysql.connector.Error as err:
    print("Error:", err)

finally:
    if cursor:
        cursor.close()
    if conn:
        conn.close()
